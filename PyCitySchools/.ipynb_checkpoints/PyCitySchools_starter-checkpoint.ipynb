# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# read merged files
school_data_complete.head(5)
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# idenfity schools
total_schools = len(school_data_complete["school_name"].unique())
print(total_schools)
# Out:
# 15

# %%
# count students
# total_students = len(school_data_complete["size"])
#len(school_data_complete)
total_students = school_data_complete["student_name"].count()
print(total_students)
# Out:
# 39170

# %%
# total budget - use read file 'school_data' to total budget from school file only             
total_budget = (school_data)["budget"].sum()
#school_data_complete.budget.count()
print(total_budget)
# Out:
# 24649428

# %%
# ave math score
ave_math = (school_data_complete)["math_score"].mean()
print(ave_math)
# Out:
# 78.98537145774827

# %%
# ave reading score
ave_reading = (school_data_complete["reading_score"]).mean()

print(ave_reading)
# Out:
# 81.87784018381414

# %%
# percentage of students with a passing math score (70 or greater)   

#Number of students who passed
percent_pass_math_df = school_data_complete.loc[school_data_complete['math_score']>=70,:]
percent_pass_math_df

#Get the percentage
percent_pass_math = len(percent_pass_math_df)/len(school_data_complete)*100
#percent_pass_math

# %%
# percentage of students with a passing reading score (70 or greater)

#Number of students who passed
percent_pass_reading_df= school_data_complete.loc[school_data_complete['reading_score']>=70,:]
percent_pass_reading_df

#Get the percentage
percent_pass_reading = len(percent_pass_reading_df)/len(school_data_complete)*100
#percent_pass_reading

# %%
# percentage of students who passed math and reading
# percent_pass_both = (len(percent_pass_math)/len(school_data_complete)) * (len(percent_pass_reading)/len(school_data_complete))*100
percent_pass_both = school_data_complete.loc[(school_data_complete['reading_score']>=70) & (school_data_complete['math_score']>=70), 'Student ID'].count()/len(school_data_complete)*100
print(percent_pass_both)
# Out:
# 65.17232575950983

# %%
#school_data_complete.loc[(school_data_complete['reading_score']>=70) & (school_data_complete['math_score']>=70),:]

# %%
# create data frame                                                  # refer to  GoodReadsSummary.ipynb 
district_summary = pd.DataFrame({"Total Schools": [total_schools],
                "Total Students": [total_students],
                "Total Budget": [total_budget],
                "Average Math Score": [ave_math],
                "Average Reading Score": [ave_reading],
                "% Passing Math": [percent_pass_math],
                "% Passing Reading": [percent_pass_reading],
                "% Overall Passing": [percent_pass_both]})

district_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# group school summary by school
grouped_schools_df = school_data_complete.set_index("school_name").groupby(["school_name"])

# In order to be visualized, a data function must be used...
grouped_schools_df
print(grouped_schools_total_students)
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: Student ID, dtype: int64

# %%
# school type                                                
grouped_schools_type = school_data.set_index("school_name")["type"]  
grouped_schools_type
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
# calcualte total number of students in each school  
grouped_schools_total_students = grouped_schools_df["Student ID"].count()
print(grouped_schools_total_students)
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: Student ID, dtype: int64

# %%
# calculate total school budget
grouped_schools_budget = school_data.set_index("school_name")["budget"]
print(grouped_schools_budget)
# Out:
# school_name
# Huang High School        1910635
# Figueroa High School     1884411
# Shelton High School      1056600
# Hernandez High School    3022020
# Griffin High School       917500
# Wilson High School       1319574
# Cabrera High School      1081356
# Bailey High School       3124928
# Holden High School        248087
# Pena High School          585858
# Wright High School       1049400
# Rodriguez High School    2547363
# Johnson High School      3094650
# Ford High School         1763916
# Thomas High School       1043130
# Name: budget, dtype: int64

# %%
# calculate budget per student
grouped_schools_per_student_budget = grouped_schools_budget / grouped_schools_total_students
print(grouped_schools_per_student_budget)
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# average math score per school
grouped_schools_ave_math = grouped_schools_df["math_score"].mean()

print(grouped_schools_ave_math)
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
# average reading score per school

grouped_schools_ave_reading = grouped_schools_df["reading_score"].mean()
print(grouped_schools_ave_reading)
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# percent passing math

# percent_pass_math = school_data_complete[school_data_complete["math_score"] >= 70].groupby("school_name")["Student ID"].count()/grouped_schools_total_students 
# print(percent_pass_math)

grouped_schools_percent_pass_math = school_data_complete[school_data_complete["math_score"] >= 70].groupby("school_name")["Student ID"].count()/grouped_schools_total_students 
print(grouped_schools_percent_pass_math)
# Out:
# school_name
# Bailey High School       0.666801
# Cabrera High School      0.941335
# Figueroa High School     0.659885
# Ford High School         0.683096
# Griffin High School      0.933924
# Hernandez High School    0.667530
# Holden High School       0.925059
# Huang High School        0.656839
# Johnson High School      0.660576
# Pena High School         0.945946
# Rodriguez High School    0.663666
# Shelton High School      0.938671
# Thomas High School       0.932722
# Wilson High School       0.938677
# Wright High School       0.933333
# Name: Student ID, dtype: float64

# %%
# percent passing reading
# percent_pass_reading = school_data_complete[school_data_complete["reading_score"] >= 70].groupby("school_name")["Student ID"].count()/grouped_schools_total_students 
# print(percent_pass_reading)

grouped_schools_percent_pass_reading = school_data_complete[school_data_complete["reading_score"] >= 70].groupby("school_name")["Student ID"].count()/grouped_schools_total_students 
print(grouped_schools_percent_pass_reading)
# Out:
# school_name
# Bailey High School       0.819333
# Cabrera High School      0.970398
# Figueroa High School     0.807392
# Ford High School         0.792990
# Griffin High School      0.971390
# Hernandez High School    0.808630
# Holden High School       0.962529
# Huang High School        0.813164
# Johnson High School      0.812224
# Pena High School         0.959459
# Rodriguez High School    0.802201
# Shelton High School      0.958546
# Thomas High School       0.973089
# Wilson High School       0.965396
# Wright High School       0.966111
# Name: Student ID, dtype: float64

# %%
# percent passing overall
grouped_schools_percent_pass_overall = (percent_pass_math * percent_pass_reading)*100
print(grouped_schools_percent_pass_overall)
# Out:
# school_name
# Bailey High School       54.633164
# Cabrera High School      91.346964
# Figueroa High School     53.278586
# Ford High School         54.168841
# Griffin High School      90.720382
# Hernandez High School    53.978451
# Holden High School       89.039593
# Huang High School        53.411814
# Johnson High School      53.653550
# Pena High School         90.759679
# Rodriguez High School    53.239316
# Shelton High School      89.975980
# Thomas High School       90.762094
# Wilson High School       90.619558
# Wright High School       90.170370
# Name: Student ID, dtype: float64

# %%
# create data frame                                                       # refer to  GoodReadsSummary.ipynb 
school_summary = pd.DataFrame({
                "School Type": grouped_schools_type,
                "Total Students": grouped_schools_total_students,
                "Total Budget": grouped_schools_per_student_budget,
                "Toal Budget Per Student": grouped_schools_per_student_budget,
                "Average Math Score": grouped_schools_ave_math,
                "Average Reading Score": grouped_schools_ave_reading,
                "% Passing Math": grouped_schools_percent_pass_math,
                "% Passing Reading": grouped_schools_percent_pass_reading,
                "% Overall Passing": grouped_schools_percent_pass_overall})

school_summary
# Out:
#                       School Type  Total Students  Total Budget  \
# Bailey High School       District            4976         628.0
# Cabrera High School       Charter            1858         582.0
# Figueroa High School     District            2949         639.0
# Ford High School         District            2739         644.0
# Griffin High School       Charter            1468         625.0
# Hernandez High School    District            4635         652.0
# Holden High School        Charter             427         581.0
# Huang High School        District            2917         655.0
# Johnson High School      District            4761         650.0
# Pena High School          Charter             962         609.0
# Rodriguez High School    District            3999         637.0
# Shelton High School       Charter            1761         600.0
# Thomas High School        Charter            1635         638.0
# Wilson High School        Charter            2283         578.0
# Wright High School        Charter            1800         583.0
#
#                        Toal Budget Per Student  Average Math Score  \
# Bailey High School                       628.0           77.048432
# Cabrera High School                      582.0           83.061895
# Figueroa High School                     639.0           76.711767
# Ford High School                         644.0           77.102592
# Griffin High School                      625.0           83.351499
# Hernandez High School                    652.0           77.289752
# Holden High School                       581.0           83.803279
# Huang High School                        655.0           76.629414
# Johnson High School                      650.0           77.072464
# Pena High School                         609.0           83.839917
# Rodriguez High School                    637.0           76.842711
# Shelton High School                      600.0           83.359455
# Thomas High School                       638.0           83.418349
# Wilson High School                       578.0           83.274201
# Wright High School                       583.0           83.682222
#
#                        Average Reading Score  % Passing Math  \
# Bailey High School                 81.033963        0.666801
# Cabrera High School                83.975780        0.941335
# Figueroa High School               81.158020        0.659885
# Ford High School                   80.746258        0.683096
# Griffin High School                83.816757        0.933924
# Hernandez High School              80.934412        0.667530
# Holden High School                 83.814988        0.925059
# Huang High School                  81.182722        0.656839
# Johnson High School                80.966394        0.660576
# Pena High School                   84.044699        0.945946
# Rodriguez High School              80.744686        0.663666
# Shelton High School                83.725724        0.938671
# Thomas High School                 83.848930        0.932722
# Wilson High School                 83.989488        0.938677
# Wright High School                 83.955000        0.933333
#
#                        % Passing Reading  % Overall Passing
# Bailey High School              0.819333          54.633164
# Cabrera High School             0.970398          91.346964
# Figueroa High School            0.807392          53.278586
# Ford High School                0.792990          54.168841
# Griffin High School             0.971390          90.720382
# Hernandez High School           0.808630          53.978451
# Holden High School              0.962529          89.039593
# Huang High School               0.813164          53.411814
# Johnson High School             0.812224          53.653550
# Pena High School                0.959459          90.759679
# Rodriguez High School           0.802201          53.239316
# Shelton High School             0.958546          89.975980
# Thomas High School              0.973089          90.762094
# Wilson High School              0.965396          90.619558
# Wright High School              0.966111          90.170370

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# Sort and display the top five performing schools by % overall passing
top_performing_schools_df = school_summary.sort_values("% Overall Passing", ascending=[False])
top_performing_schools_df.head()
# Out:
#                     School Type  Total Students  Total Budget  \
# Cabrera High School     Charter            1858         582.0
# Thomas High School      Charter            1635         638.0
# Pena High School        Charter             962         609.0
# Griffin High School     Charter            1468         625.0
# Wilson High School      Charter            2283         578.0
#
#                      Toal Budget Per Student  Average Math Score  \
# Cabrera High School                    582.0           83.061895
# Thomas High School                     638.0           83.418349
# Pena High School                       609.0           83.839917
# Griffin High School                    625.0           83.351499
# Wilson High School                     578.0           83.274201
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780        0.941335           0.970398
# Thomas High School               83.848930        0.932722           0.973089
# Pena High School                 84.044699        0.945946           0.959459
# Griffin High School              83.816757        0.933924           0.971390
# Wilson High School               83.989488        0.938677           0.965396
#
#                      % Overall Passing
# Cabrera High School          91.346964
# Thomas High School           90.762094
# Pena High School             90.759679
# Griffin High School          90.720382
# Wilson High School           90.619558

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
# sort_values()
# Sort and display the bottom five performing schools by % overall passing
top_performing_schools_df = school_summary.sort_values("% Overall Passing", ascending=[True])
top_performing_schools_df.head()
# Out:
#                       School Type  Total Students  Total Budget  \
# Rodriguez High School    District            3999         637.0
# Figueroa High School     District            2949         639.0
# Huang High School        District            2917         655.0
# Johnson High School      District            4761         650.0
# Hernandez High School    District            4635         652.0
#
#                        Toal Budget Per Student  Average Math Score  \
# Rodriguez High School                    637.0           76.842711
# Figueroa High School                     639.0           76.711767
# Huang High School                        655.0           76.629414
# Johnson High School                      650.0           77.072464
# Hernandez High School                    652.0           77.289752
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686        0.663666
# Figueroa High School               81.158020        0.659885
# Huang High School                  81.182722        0.656839
# Johnson High School                80.966394        0.660576
# Hernandez High School              80.934412        0.667530
#
#                        % Passing Reading  % Overall Passing
# Rodriguez High School           0.802201          53.239316
# Figueroa High School            0.807392          53.278586
# Huang High School               0.813164          53.411814
# Johnson High School             0.812224          53.653550
# Hernandez High School           0.808630          53.978451

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Create a pandas series for each grade
nine = student_data.loc[student_data["grade"] == '9th']
ten = student_data.loc[student_data["grade"] == '10th']
eleven = student_data.loc[student_data["grade"] == '11th']
twelve = student_data.loc[student_data["grade"] == '12th']

# %%
# group by school
nine_group = nine.groupby("school_name")["math_score"].mean()
ten_group = ten.groupby("school_name")["math_score"].mean()
eleven_group = eleven.groupby("school_name")["math_score"].mean()
twelve_group = twelve.groupby("school_name")["math_score"].mean()

# %%
# create df
math_scores = pd.DataFrame({"9th": nine_group, 
                            "10th": ten_group, 
                            "11th": eleven_group, 
                            "12th": twelve_group})

math_scores
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# Wilson High School     83.085578  83.724422  83.195326  83.035794
# Wright High School     83.264706  84.010288  83.836782  83.644986

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Create a pandas series for each grade
#nine = student_data.loc[student_data["grade"] == '9th']
#ten = student_data.loc[student_data["grade"] == '10th']
#eleven = student_data.loc[student_data["grade"] == '11th']
#twelve = student_data.loc[student_data["grade"] == '12th']

# %%
# group by school
nine_read_group = nine.groupby("school_name")["reading_score"].mean()
ten_read_group = ten.groupby("school_name")["reading_score"].mean()
eleven_read_group = eleven.groupby("school_name")["reading_score"].mean()
twelve_read_group = twelve.groupby("school_name")["reading_score"].mean()

# %%
# create df
reading_scores = pd.DataFrame({"9th": nine_read_group, 
                            "10th": ten_read_group, 
                            "11th": eleven_read_group, 
                            "12th": twelve_read_group})

reading_scores
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# Wilson High School     83.939778  84.021452  83.764608  84.317673
# Wright High School     83.833333  83.812757  84.156322  84.073171

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# copy datafram
school_summary = pd.DataFrame({
                "School Type": grouped_schools_type,
                "Total Students": grouped_schools_total_students,
                "Total Budget": grouped_schools_per_student_budget,
                "Total Budget Per Student": grouped_schools_per_student_budget,
                "Average Math Score": grouped_schools_ave_math,
                "Average Reading Score": grouped_schools_ave_reading,
                "% Passing Math": grouped_schools_percent_pass_math,
                "% Passing Reading": grouped_schools_percent_pass_reading,
                "% Overall Passing": grouped_schools_percent_pass_overall})
                         
# # use school_summary dataframe per LinLin
# # school_summary.dtypes

# %%
# create bins and labels    
bins = [0, 584, 630, 644, 700]
group_labels = ['<$585', '$585-630', '$630-645', '$645-680']

# %%
# Slice the data and place it into bins
school_summary["Spending Ranges"] = pd.cut(school_summary["Total Budget Per Student"], bins, labels=group_labels)

# %%
# create group based off bins
school_spending_summary = school_summary.groupby("Spending Ranges")
school_spending_summary.mean()
# Out:
#                  Total Students  Total Budget  Total Budget Per Student  \
# Spending Ranges
# <$585               1592.000000    581.000000                581.000000
# $585-630            2291.750000    615.500000                615.500000
# $630-645            2830.500000    639.500000                639.500000
# $645-680            4104.333333    652.333333                652.333333
#
#                  Average Math Score  Average Reading Score  % Passing Math  \
# Spending Ranges
# <$585                     83.455399              83.933814        0.934601
# $585-630                  81.899826              83.155286        0.871335
# $630-645                  78.518855              81.624473        0.734842
# $645-680                  76.997210              81.027843        0.661648
#
#                  % Passing Reading  % Overall Passing
# Spending Ranges
# <$585                     0.966109          90.294121
# $585-630                  0.927182          81.522301
# $630-645                  0.843918          62.862209
# $645-680                  0.811340          53.681272

# %%
# remove unecessary columms by identifying the ones keep

# school_spending_summary = school_spending_summary(columns={"Average Math Score": "ave_math",
#                                                     "Average Reading Score": "ave_reading",                                                      
#                                                     "% Passing Math": "grouped_schools_percent_pass_math",
#                                                      "% Passing Reading": "grouped_schools_percent_pass_reading",
#                                                       "% Overall Passing": "grouped_schools_percent_pass_overall" })
# school_spending_summary

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Ask-BCS recommended new variables for new DF, to include the grouby
# school_types = school_data.set_index(['school_name'])['type']
# total_students = school_data_complete.groupby(['school_name']).mean()['total_students']
# per_school_budget = school_data_complete.groupby(['school_name']).mean()['budget']
# per_student_budget = school_data_complete.groupby(['school_name']).mean()['student_budget']
# per_school_math = school_data_complete.groupby(['school_name']).mean()['math_score']
# per_school_read = school_data_complete.groupby(['school_name']).mean()['read_score']
# percent_math = school_data_complete.groupby(['school_name']).mean()['percent_pass_math']
# percent_read = school_data_complete.groupby(['school_name']).mean()['percent_pass_read']
# percent_both = school_data_complete.groupby(['school_name']).mean()['percent_pass_both']

# %%
# Ask-BCS recommend new datafram
# school_summary2 = pd.DataFrame({
#                     "School Type": school_types,
#                     "Total Students": total_students,
#                     "Total Budget": per_school_budget,
#                     "Total Budget Per Student": per_student_budget,
#                     "Average Math Score": per_school_math,
#                     "Average Read Score": per_school_read,
#                     "% Passing Math": percent_pass_math,
#                     "% Passing Reading": percent_pass_read,
#                     "% Overall Passing": percent_pass_both})

# school_summary2

# %%
# copy original dataframe
school_summary = pd.DataFrame({
                "School Type": [grouped_schools_type],
                "Total Students": [grouped_schools_total_students], #grouped_schools_total_students = grouped_schools_df["Student ID"].count()
                "Total Budget": [grouped_schools_per_student_budget],
                "Total Budget Per Student": [grouped_schools_per_student_budget],
                "Average Math Score": [grouped_schools_ave_math],
                "Average Reading Score": [grouped_schools_ave_reading],
                "% Passing Math": [grouped_schools_percent_pass_math],
                "% Passing Reading": [grouped_schools_percent_pass_reading],
                "% Overall Passing": [grouped_schools_percent_pass_overall]})

# %%
# create bins and labels    
bins = [0, 50, 75, 100]
group_labels = ['Small (<1000)', 'Medium (1000-2000)', 'Large (2000-5000)']

# %%
# school_summary.drop(columns=['School Size'])
# school_summary.head()

# %%
# Slice the data and place it into bins  #grouped_schools_df
#district_summary["School Size"] = pd.cut(district_summary['Total Students'], bins=bins,labels=group_labels)

# Categorize spending based on the bins.
school_summary["School Size"] = pd.cut(school_summary["Total Students"], size_bins, labels=group_labels)

school_summary.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-333-e8ec387041ef> in <module>
#       3
#       4 # Categorize spending based on the bins.
# ----> 5 school_summary["School Size"] = pd.cut(school_summary["Total Students"], size_bins, labels=group_labels)
#       6
#       7 school_summary.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     255             raise ValueError("bins must increase monotonically.")
#     256
# --> 257     fac, bins = _bins_to_cuts(
#     258         x,
#     259         bins,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     386
#     387     side = "left" if right else "right"
# --> 388     ids = ensure_int64(bins.searchsorted(x, side=side))
#     389
#     390     if include_lowest:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# group by type of school
school_summary = school_summary.groupby("School Size")
school_summary.mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-334-ead189d9dddf> in <module>
#       1 # group by type of school
# ----> 2 school_summary = school_summary.groupby("School Size")
#       3 school_summary.mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5799         axis = self._get_axis_number(axis)
#    5800
# -> 5801         return groupby_generic.DataFrameGroupBy(
#    5802             obj=self,
#    5803             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     401             from pandas.core.groupby.grouper import get_grouper
#     402
# --> 403             grouper, exclusions, obj = get_grouper(
#     404                 obj,
#     405                 keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     598                 in_axis, name, level, gpr = False, None, gpr, None
#     599             else:
# --> 600                 raise KeyError(gpr)
#     601         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     602             # Add key to exclusions
#
# KeyError: 'School Size'

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# copy dataframe to create Scores by School Type
school_summary = pd.DataFrame({
                "School Type": grouped_schools_type,
                "Total Students": grouped_schools_total_students,
                "Total Budget": grouped_schools_per_student_budget,
                "Total Budget Per Student": grouped_schools_per_student_budget,
                "Average Math Score": grouped_schools_ave_math,
                "Average Reading Score": grouped_schools_ave_reading,
                "% Passing Math": grouped_schools_percent_pass_math,
                "% Passing Reading": grouped_schools_percent_pass_reading,
                "% Overall Passing": grouped_schools_percent_pass_overall})
                         
#school_summary.dtypes

# %%
# school_type_summary = school_summary.loc[:, ["Average Math Score", "Average Reading Score",
#                                      "Percent Passing Math", "Percent Passing Reading",
#                                      "Overall Passing Rate"]]
# school_type_summary

# %%
# group by type of school
groupby_type = school_data_complete.groupby("type")
print(groupby_type)
groupby_type.max()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000002287C5D4460>
#           Student ID student_name gender grade            school_name  \
# type
# Charter        39169    Zoe Mayer      M   9th     Wright High School
# District       37534    Zoe Meyer      M   9th  Rodriguez High School
#
#           reading_score  math_score  School ID  size   budget
# type
# Charter              99          99         14  2283  1319574
# District             99          99         13  4976  3124928
